# %%
import pandas as pd

df = pd.read_csv('./data/ad_placement/census-income.csv')
                 
df.columns = ['AAGE','ACLSWKR','ADTIND','ADTOCC','AHGA','AHRSPAY','AHSCOL','AMARITL',
                                                                              'AMJIND','AMJOCC','ARACE','AREORGN','ASEX','AUNMEM','AUNTYPE','AWKSTAT','CAPGAIN',
                                                                              'CAPLOSS','DIVVAL','FILESTAT','GRINREG','GRINST','HHDFMX','HHDREL', 'MARSUPWT',
                                                                              'MIGMTR1','MIGMTR3','MIGMTR4','MIGSAME','MIGSUN','NOEMP','PARENT','PEFNTVTY',
                                                                              'PEMNTVTY','PENATVTY','PRCITSHP','SEOTR','VETQVA','VETYN','WKSWORK', 'YEAR', 'INCOME']

# %%
df.to_excel('testing.xlsx')

# %%
df
# Out:
#         AAGE                          ACLSWKR  ADTIND  ADTOCC  \
# 0         58   Self-employed-not incorporated       4      34
# 1         18                  Not in universe       0       0
# 2          9                  Not in universe       0       0
# 3         10                  Not in universe       0       0
# 4         48                          Private      40      10
# 5         42                          Private      34       3
# 6         28                          Private       4      40
# 7         47                 Local government      43      26
# 8         34                          Private       4      37
# 9          8                  Not in universe       0       0
# 10        32                  Not in universe       0       0
# 11        51                          Private       4      34
# 12        46                          Private      37      31
# 13        26                          Private      24      12
# ...

# %%
df.AHGA.value_counts()
len(df)
# Out:
# 199522

# %%
df[['AAGE','ACLSWKR','ADTIND','ADTOCC','AHGA','AHRSPAY','AMARITL','ARACE','ASEX','AUNTYPE','AWKSTAT','CAPGAIN',
          'CAPLOSS','DIVVAL','FILESTAT','HHDREL','MIGMTR1','NOEMP','PARENT','SEOTR','VETYN','WKSWORK', 'YEAR', 'INCOME']]
# Out:
#         AAGE                          ACLSWKR  ADTIND  ADTOCC  \
# 0         58   Self-employed-not incorporated       4      34
# 1         18                  Not in universe       0       0
# 2          9                  Not in universe       0       0
# 3         10                  Not in universe       0       0
# 4         48                          Private      40      10
# 5         42                          Private      34       3
# 6         28                          Private       4      40
# 7         47                 Local government      43      26
# 8         34                          Private       4      37
# 9          8                  Not in universe       0       0
# 10        32                  Not in universe       0       0
# 11        51                          Private       4      34
# 12        46                          Private      37      31
# 13        26                          Private      24      12
# ...

# %%
df.dtypes
# Out:
# AAGE          int64
# ACLSWKR      object
# ADTIND        int64
# ADTOCC        int64
# AHGA         object
# AHRSPAY       int64
# AHSCOL       object
# AMARITL      object
# AMJIND       object
# AMJOCC       object
# ARACE        object
# AREORGN      object
# ASEX         object
# AUNMEM       object
# AUNTYPE      object
# AWKSTAT      object
# CAPGAIN       int64
# CAPLOSS       int64
# DIVVAL        int64
# FILESTAT     object
# GRINREG      object
# GRINST       object
# HHDFMX       object
# HHDREL       object
# MARSUPWT    float64
# MIGMTR1      object
# MIGMTR3      object
# MIGMTR4      object
# MIGSAME      object
# MIGSUN       object
# NOEMP         int64
# PARENT       object
# PEFNTVTY     object
# PEMNTVTY     object
# PENATVTY     object
# PRCITSHP     object
# SEOTR         int64
# VETQVA       object
# VETYN         int64
# WKSWORK       int64
# YEAR          int64
# INCOME       object
# dtype: object

# %%
df_dummies=pd.get_dummies(df)
df_reduced=df[['AAGE','ADTIND','ADTOCC','AHRSPAY','CAPGAIN','CAPLOSS','DIVVAL','NOEMP','SEOTR','VETYN','WKSWORK', 'YEAR']]

# %%
df_reduced.head()
# Out:
#    AAGE  ADTIND  ADTOCC  AHRSPAY  CAPGAIN  CAPLOSS  DIVVAL  NOEMP  SEOTR  \
# 0    58       4      34        0        0        0       0      1      0
# 1    18       0       0        0        0        0       0      0      0
# 2     9       0       0        0        0        0       0      0      0
# 3    10       0       0        0        0        0       0      0      0
# 4    48      40      10     1200        0        0       0      1      2
#
#    VETYN  WKSWORK  YEAR
# 0      2       52    94
# 1      2        0    95
# 2      0        0    94
# 3      0        0    94
# 4      2       52    95

# %%
from sklearn.cluster import KMeans
